# %%
import pandas as pd
from IPython.display import display
from Main import Room

df = pd.read_json("deviation.json")

plotter = Room()

plot_paths = plotter.draw_plots(df)

styled_df = df.style.set_table_styles([
    {'selector': 'thead th', 'props': [('background-color', 'lightgrey')]}
])

# Отображение таблицы и путей к графикам
display(styled_df)

# Отображение изображений графиков
for plot_path in plot_paths:
    display(plot_path)
# Out:
# <style type="text/css">
# #T_40e5b thead th {
#   background-color: lightgrey;
# }
# </style>
# <table id="T_40e5b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40e5b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_40e5b_level0_col1" class="col_heading level0 col1" >gt_corners</th>
#       <th id="T_40e5b_level0_col2" class="col_heading level0 col2" >rb_corners</th>
#       <th id="T_40e5b_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_40e5b_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_40e5b_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_40e5b_level0_col6" class="col_heading level0 col6" >floor_mean</th>
#       <th id="T_40e5b_level0_col7" class="col_heading level0 col7" >floor_max</th>
#       <th id="T_40e5b_level0_col8" class="col_heading level0 col8" >floor_min</th>
# ...
